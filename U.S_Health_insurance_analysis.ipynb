# %% [markdown]
# # **Why perform EDA?**
#
# - Model building
# - Analysis and reporting
# - Validate assumptions
# - Handling missing values
# - Feature engineering
# - Detecting outliers

# %% [markdown]
# # **Importing the Dataset and the required libraries**
#
#   #### `Dataset used` -> [US Health Insurance]( https://www.kaggle.com/datasets/teertha/ushealthinsurancedataset)
#
#   This dataset contains 1338 rows of insured data, where the Insurance charges are given against the following attributes of the insured: Age, Sex, BMI, Number of Children, Smoker and Region. There are no missing or undefined values in the dataset.

# %%
# Importing some of the most important libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# plt.style.available
plt.style.use('seaborn-v0_8-darkgrid')       # Setting the plot style

# %%
# Reading the CSV file
df=pd.read_csv('/content/PCA-2 EDA Insurance.csv')
df
# Out:
#       age     sex     bmi  children smoker     region      charges
# 0      19  female  27.900         0    yes  southwest  16884.92400
# 1      18    male  33.770         1     no  southeast   1725.55230
# 2      28    male  33.000         3     no  southeast   4449.46200
# 3      33    male  22.705         0     no  northwest  21984.47061
# 4      32    male  28.880         0     no  northwest   3866.85520
# ...   ...     ...     ...       ...    ...        ...          ...
# 1333   50    male  30.970         3     no  northwest  10600.54830
# 1334   18  female  31.920         0     no  northeast   2205.98080
# 1335   18  female  36.850         0     no  southeast   1629.83350
# 1336   21  female  25.800         0     no  southwest   2007.94500
# 1337   61  female  29.070         0    yes  northwest  29141.36030
#
# [1338 rows x 7 columns]

# %%
# Viewing a few rows from the beginning
df.head(3)
# Out:
#    age     sex    bmi  children smoker     region     charges
# 0   19  female  27.90         0    yes  southwest  16884.9240
# 1   18    male  33.77         1     no  southeast   1725.5523
# 2   28    male  33.00         3     no  southeast   4449.4620

# %%
# Viewing a few rows from the end
df.head(3)
# Out:
#    age     sex    bmi  children smoker     region     charges
# 0   19  female  27.90         0    yes  southwest  16884.9240
# 1   18    male  33.77         1     no  southeast   1725.5523
# 2   28    male  33.00         3     no  southeast   4449.4620

# %%
# Viewing random samples
df.sample(10)
# Out:
#       age     sex     bmi  children smoker     region      charges
# 595    46  female  33.725         1     no  northeast   8823.98575
# 641    42    male  28.310         3    yes  northwest  32787.45859
# 929    41    male  34.210         1     no  southeast   6289.75490
# 1032   30  female  27.930         0     no  northeast   4137.52270
# 395    46    male  19.855         0     no  northwest   7526.70645
# 1162   30    male  38.830         1     no  southeast  18963.17192
# 475    61    male  28.310         1    yes  northwest  28868.66390
# 17     23    male  23.845         0     no  northeast   2395.17155
# 496    31  female  23.600         2     no  southwest   4931.64700
# 869    25  female  24.300         3     no  southwest   4391.65200

# %% [markdown]
# # **Performing some Basic Analyses**

# %%
# Get information about the DataFrame
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1338 entries, 0 to 1337
# Data columns (total 7 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   age       1338 non-null   int64
#  1   sex       1338 non-null   object
#  2   bmi       1338 non-null   float64
#  3   children  1338 non-null   int64
#  4   smoker    1338 non-null   object
#  5   region    1338 non-null   object
#  6   charges   1338 non-null   float64
# dtypes: float64(2), int64(2), object(3)
# memory usage: 73.3+ KB

# %% [markdown]
# ***We can clearly see that there are no missing values in this dataset. So there's no need to check for them explicitly.***

# %%
# Getting the statistics of all the numerical columns of this dataframe
df.describe()
# Out:
#                age          bmi     children       charges
# count  1338.000000  1338.000000  1338.000000   1338.000000
# mean     39.207025    30.663397     1.094918  13270.422265
# std      14.049960     6.098187     1.205493  12110.011237
# min      18.000000    15.960000     0.000000   1121.873900
# 25%      27.000000    26.296250     0.000000   4740.287150
# 50%      39.000000    30.400000     1.000000   9382.033000
# 75%      51.000000    34.693750     2.000000  16639.912515
# max      64.000000    53.130000     5.000000  63770.428010

# %% [markdown]
# # **Univariate Analysis**
#
# Univariate analysis focuses on analyzing each feature in the dataset independently.
#
# - **Distribution analysis**: The distribution of each feature is examined to identify its shape, central tendency, and dispersion.
#
# - **Identifying potential issues**: Univariate analysis helps in identifying potential problems with the data such as outliers, skewness, and missing values

# %%
df.head()
# Out:
#    age     sex     bmi  children smoker     region      charges
# 0   19  female  27.900         0    yes  southwest  16884.92400
# 1   18    male  33.770         1     no  southeast   1725.55230
# 2   28    male  33.000         3     no  southeast   4449.46200
# 3   33    male  22.705         0     no  northwest  21984.47061
# 4   32    male  28.880         0     no  northwest   3866.85520

# %% [markdown]
# ## Steps of doing Univariate Analysis on Numerical columns
#
# - **Descriptive Statistics**: Compute basic summary statistics for the column, such as mean, median, mode, standard deviation, range, and quartiles. These statistics give a general understanding of the distribution of the data and can help identify skewness or outliers.
#
# - **Visualizations**: Create visualizations to explore the distribution of the data. Some common visualizations for numerical data include histograms, box plots, and density plots. These visualizations provide a visual representation of the distribution of the data and can help identify skewness an outliers.
#
# - **Identifying Outliers**: Identify and examine any outliers in the data. Outliers can be identified using visualizations. It is important to determine whether the outliers are due to measurement errors, data entry errors, or legitimate differences in the data, and to decide whether to include or exclude them from the analysis.
#
# - **Skewness**: Check for skewness in the data and consider transforming the data or using robust statistical methods that are less sensitive to skewness, if necessary.
#
# - **Conclusion**: Summarize the findings of the EDA and make decisions about how to proceed with further analysis.

# %%
df.describe()
# Out:
#                age          bmi     children       charges
# count  1338.000000  1338.000000  1338.000000   1338.000000
# mean     39.207025    30.663397     1.094918  13270.422265
# std      14.049960     6.098187     1.205493  12110.011237
# min      18.000000    15.960000     0.000000   1121.873900
# 25%      27.000000    26.296250     0.000000   4740.287150
# 50%      39.000000    30.400000     1.000000   9382.033000
# 75%      51.000000    34.693750     2.000000  16639.912515
# max      64.000000    53.130000     5.000000  63770.428010

# %%
# Plotting a histogram of the numerical (continuous) columns

plt.figure(figsize=(13,5))

plt.subplot(1,3,1)
df['age'].plot(kind='hist',bins=10)
plt.xlabel('Age Values')
plt.title('Age Histogram')

plt.subplot(1,3,2)
df['bmi'].plot(kind='hist',bins=10,color='brown')
plt.xlabel('BMI Values')
plt.title('BMI Histogram')

plt.subplot(1,3,3)
df['charges'].plot(kind='hist',color='g')
plt.xticks(rotation=70)
plt.xlabel('Charges Values')
plt.title('Charges Histogram')

plt.suptitle('Histograms of all the Numerical Columns')

plt.tight_layout()
plt.show()

# %%
# Plotting KDE-plots of the numerical (continuous) columns to visualize the distributions

plt.figure(figsize=(13,4))

plt.subplot(1,3,1)
sns.kdeplot(df['age'])
plt.title('Distribution of the "Ages"')

plt.subplot(1,3,2)
sns.kdeplot(df['bmi'])
plt.title('Distribution of the "BMIs"')

plt.subplot(1,3,3)
sns.kdeplot(df['charges'])
plt.title('Distribution of the "Charges')

plt.suptitle('Distributions of all the Numerical Columns')

plt.tight_layout()
plt.show()

print()

print('_'*185)

print()
print(f'Skewness of "age": {df["age"].skew():.2f}')
print(f'Skewness of "bmi": {df["bmi"].skew():.2f}')
print(f'Skewness of "charges": {df["charges"].skew():.2f}')
# Out:
# _________________________________________________________________________________________________________________________________________________________________________________________
#
# Skewness of "age": 0.06
# Skewness of "bmi": 0.28
# Skewness of "charges": 1.52

# %% [markdown]
# ***We can figure out from the above visualizations and the skewness values that only the `BMI` column is normally distributed***

# %%
# Plotting box-plots to find out the outliers
plt.figure(figsize=(12,5))

plt.subplot(1,3,1)
sns.boxplot(df['age'])
plt.title('Box-plot of the "Ages"')

plt.subplot(1,3,2)
sns.boxplot(df['bmi'],color='red')
plt.title('Box-plot of the "BMIs"')

plt.subplot(1,3,3)
sns.boxplot(df['charges'],color='green')
plt.title('Box-plot of the "Charges')

plt.suptitle('Box-plot of each numerical column')

plt.tight_layout()
plt.show()

# %% [markdown]
# ### From the above visualizations we can approximate the outliers:
#
# - `Age` -> No outliers detected.
# - `BMI` -> There are quite a few outliers present. The threshold value is around 47 (as can be seen in the above graph).
# - `Charges` -> Lots of outliers are present in this column. The threshold value is around 35000 (as can be seen in the above graph).

# %% [markdown]
# ## **Steps of doing Univariate Analysis on Categorical columns**
#
# **Descriptive Statistics**: Compute the frequency distribution of the categories in the column. This will give a general understanding of the distribution of the categories and their relative frequencies.
#
# **Visualizations**: Create visualizations to explore the distribution of the categories. Some common visualizations for categorical data include count plots and pie charts. These visualizations provide a visual representation of the distribution of the categories and can help identify any patterns or anomalies in the data.
#
# **Missing Values**: Check for missing values in the data and decide how to handle them. Missing values can be imputed or excluded from the analysis, depending on the research question and the data set.
#
# **Conclusion**: Summarize the findings of the EDA and make decisions about how to proceed with further analysis.

# %%
df.head(3)
# Out:
#    age     sex    bmi  children smoker     region     charges
# 0   19  female  27.90         0    yes  southwest  16884.9240
# 1   18    male  33.77         1     no  southeast   1725.5523
# 2   28    male  33.00         3     no  southeast   4449.4620

# %% [markdown]
# #### Categorical columns in this dataset:
# - `sex`
# - `children`
# - `smoker`
# - `region`

# %%
df['sex'].value_counts()
# Out:
# male      676
# female    662
# Name: sex, dtype: int64

# %%
# Showing the distribution of males and females

plt.figure(figsize=(12,4))

plt.subplot(1,2,1)
sns.countplot(x='sex',data=df)

plt.subplot(1,2,2)
df['sex'].value_counts().plot(kind='pie',autopct='%0.01f%%')

plt.suptitle('Males vs Females')

plt.tight_layout()
plt.show()

# %%
df['children'].value_counts()
# Out:
# 0    574
# 1    324
# 2    240
# 3    157
# 4     25
# 5     18
# Name: children, dtype: int64

# %%
# Plotting the distribution of the number of children

plt.figure(figsize=(12,4))

plt.subplot(1,2,1)
sns.countplot(x='children',data=df)

plt.subplot(1,2,2)
df['children'].value_counts().plot(kind='pie',autopct='%0.01f%%')

plt.suptitle('Number of Children')

plt.tight_layout()
plt.show()

# %%
df['smoker'].value_counts()
# Out:
# no     1064
# yes     274
# Name: smoker, dtype: int64

# %%
# Plotting the distribution of the number of smokers and non-smokers

plt.figure(figsize=(12,4))

plt.subplot(1,2,1)
sns.countplot(x='smoker',data=df)

plt.subplot(1,2,2)
df['smoker'].value_counts().plot(kind='pie',autopct='%0.01f%%')

plt.suptitle('Smoker vs Non-smoker')

plt.tight_layout()
plt.show()

# %%
df['region'].value_counts()
# Out:
# southeast    364
# southwest    325
# northwest    325
# northeast    324
# Name: region, dtype: int64

# %%
# Plotting the distribution of the regions

plt.figure(figsize=(12,4))

plt.subplot(1,2,1)
sns.countplot(x='region',data=df)

plt.subplot(1,2,2)
df['region'].value_counts().plot(kind='pie',autopct='%0.01f%%')

plt.suptitle('Regions')

plt.tight_layout()
plt.show()

# %% [markdown]
# ## **Steps of doing Bivariate Analysis**
#
# - Select 2 columns
# - Understand type of relationship
#     1. **Numerical - Numerical**<br>
#         a. You can plot graphs like scatterplot(regression plots), 2D histplot, 2D KDEplots<br>
#         b. Check correlation coefficent to check linear relationship
#     2. **Numerical - Categorical** - create visualizations that compare the distribution of the numerical data across different categories of the categorical data.<br>
#         a. You can plot graphs like barplot, boxplot, kdeplot violinplot even scatterplots<br>
#     3. **Categorical - Categorical**<br>
#         a. You can create cross-tabulations or contingency tables that show the distribution of values in one categorical column, grouped by the values in the other categorical column.<br>
#         b. You can plots like heatmap, stacked barplots, treemaps
#
# - Write your conclusions

# %% [markdown]
# #### **Bi-variate Analysis of 2 Numerical Columns**

# %%
df.head()
# Out:
#    age     sex     bmi  children smoker     region      charges
# 0   19  female  27.900         0    yes  southwest  16884.92400
# 1   18    male  33.770         1     no  southeast   1725.55230
# 2   28    male  33.000         3     no  southeast   4449.46200
# 3   33    male  22.705         0     no  northwest  21984.47061
# 4   32    male  28.880         0     no  northwest   3866.85520

# %%
# Plotting the relationship between the numerical columns

plt.figure(figsize=(20,10))
sns.pairplot(df)
plt.show()

# %%
# Correlation matrix of all the numerical columns
df.corr()
# Out:
# <ipython-input-193-a488896b33ae>:2: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.corr()
#                age       bmi  children   charges
# age       1.000000  0.109272  0.042469  0.299008
# bmi       0.109272  1.000000  0.012759  0.198341
# children  0.042469  0.012759  1.000000  0.067998
# charges   0.299008  0.198341  0.067998  1.000000

# %%
# Plotting a heatmap of the correlation matrix

sns.heatmap(df.corr())
plt.title('Correlation Matrix')
plt.tight_layout()
plt.show()
# Out:
# <ipython-input-194-3fed8ffaf232>:3: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(df.corr())

# %%
# Plotting the relationship between "BMI" and "Charges" for both males and females
sns.scatterplot(x='bmi',y='charges',data=df,hue='sex')
plt.show()

# %% [markdown]
# ***We can clearly see that there is some sort of a relationship (though not completely linear) between these columns.***

# %%
# Plotting the relationship between "Age" and "Charges" for both males and females
sns.scatterplot(x='age',y='charges',data=df,hue='sex')
plt.show()

# %% [markdown]
# ***We can clearly see that there's no relationship between these columns.***

# %% [markdown]
# #### **Numerical-Categorical Analysis**

# %%
# Plotting the mean 'charge' across different regions

df.groupby('region')['charges'].mean().plot(kind='bar',color=['red','green','brown','blue'])
plt.ylabel('Avg. Charge')
plt.title('Avg. "Charge" Across Regions')

plt.tight_layout()
plt.show()

# %%
# Plotting the mean 'charge' for smokers and non-smokers

df.groupby('smoker')['charges'].mean().plot(kind='bar',color=['red','blue'])
plt.ylabel('Avg. Charge')
plt.title('Avg. "Charge" for Smokers and Non-smokers')

plt.tight_layout()
plt.show()

# %%
# Plotting the mean 'charge' for males and females

df.groupby('sex')['charges'].mean().plot(kind='bar',color=['green','brown'])
plt.ylabel('Avg. Charge')
plt.title('Avg. "Charge" for Males and Females')

plt.tight_layout()
plt.show()

# %%
# Plotting the mean 'charge' for the number of children

df.groupby('children')['charges'].mean().plot(kind='bar')
plt.ylabel('Avg. Charge')
plt.title('Avg. "Charge" for No. of Chidren')

plt.tight_layout()
plt.show()

# %%
# Plotting the mean 'age' across the regions

df.groupby('region')['age'].mean().plot(kind='bar')
plt.ylabel('Avg. Age')
plt.title('Avg. "Age" Across Regions')

plt.tight_layout()
plt.show()

# %% [markdown]
# #### **Bi-variate analysis of 2 categorical columns**

# %%
df.head()
# Out:
#    age     sex     bmi  children smoker     region      charges
# 0   19  female  27.900         0    yes  southwest  16884.92400
# 1   18    male  33.770         1     no  southeast   1725.55230
# 2   28    male  33.000         3     no  southeast   4449.46200
# 3   33    male  22.705         0     no  northwest  21984.47061
# 4   32    male  28.880         0     no  northwest   3866.85520

# %%
pd.crosstab(df['region'],df['smoker'],normalize='columns')*100
# Out:
# smoker            no        yes
# region
# northeast  24.154135  24.452555
# northwest  25.093985  21.167883
# southeast  25.657895  33.211679
# southwest  25.093985  21.167883

# %% [markdown]
# ***This code creates a cross-tabulation table between the region and smoker columns in the dataframe df. The table is normalized by column, meaning that each column will sum to 100%. The output is multiplied by 100 to convert it to a percentage.***

# %%
# Creating a heatmap of Smokers and Non-smokers across different regions

sns.heatmap(pd.crosstab(df['region'],df['smoker'],normalize='columns')*100)
plt.title('Smokers and Non-smokers Across Different Regions')
plt.tight_layout()
plt.show()

# %%
pd.crosstab(df['region'],df['children'],normalize='columns')*100
# Out:
# children           0          1      2          3     4          5
# region
# northeast  25.609756  23.765432  21.25  24.840764  28.0  16.666667
# northwest  22.996516  22.839506  27.50  29.299363  24.0   5.555556
# southeast  27.351916  29.320988  27.50  22.292994  20.0  33.333333
# southwest  24.041812  24.074074  23.75  23.566879  28.0  44.444444

# %% [markdown]
# ***This code creates a cross-tabulation table between the region and children
# columns in the dataframe df. The table is normalized by column, meaning that each column will sum to 100%. The output is multiplied by 100 to convert it to a percentage.***

# %%
# Creating a heatmap of number of children across different regions

sns.heatmap(pd.crosstab(df['region'],df['children'],normalize='columns')*100)
plt.title('No. of Children Across Different Regions')
plt.tight_layout()
plt.show()

# %%
pd.crosstab(df['sex'],df['smoker'],normalize='columns')*100
# Out:
# smoker         no        yes
# sex
# female  51.409774  41.970803
# male    48.590226  58.029197

# %% [markdown]
# ***This code creates a cross-tabulation table between sex and smoker
# columns in the dataframe df. The table is normalized by column, meaning that each column will sum to 100%. The output is multiplied by 100 to convert it to a percentage.***

# %%
# Creating a heatmap of number of smoker vs sex

sns.heatmap(pd.crosstab(df['sex'],df['smoker'],normalize='columns')*100)
plt.title('Heatmap of Smoker and Sex')
plt.tight_layout()
plt.show()
